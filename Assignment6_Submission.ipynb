// %% [markdown]
// **Jayden Smith**
// **CS 6420 - Al-Gahmi**
// **April 2, 2021**

// %% [markdown]
// # Assignment 6

// %% [markdown]
// ## Part 1

// %% [markdown]
// For this assignment, I implement and compare the performance of the following three matrix multiplication algorithms:
// * **double* iterative_mult(int n, double* A, double* B)**: which multiplies matrix A by matrix B and returns the result based on the Square-Matrix-Multiply algorithm. Both A and B matrices are of square n×n size and you can assume that n is a power of 2.
// * **double* recursive_mult(int n, double* A, double* B)**: which multiplies matrix A by matrix B and returns the result based on the Square-Matrix-Multiply-Recursive algorithm. Both A and B matrices are of square n×n size and you can assume that n is a power of 2.
// * **double* strassen_mult(int n, double* A, double* B)**: which multiplies matrix A by matrix B and returns the result using the Strassen's method. Both A and B matrices are of square n×n size and you can assume that n is a power of 2.

// %% [markdown]
// To help with running these functions, I also implemented the following functions:
// * **bool check_equal(int n, double* A, double* B)**: which checks if two matrices are equivalent. This is used to verify during testing that the results of all three algorithms are the same.
// * **void print_in_2d(int n, double* A)**: which takes a column-major array A and prints in its a two-dimensional matrix format.
// * **double* sub_matrices(int n, double* A, double* B)**: which returns the difference of two column-major matrices
// * **double* add_matrices(int n, double* A, double* B)**: which returns the sum of two column-major matrices
//
// These functions and their implementations can be found in the **alg_matrices.cpp** file under the **src** directory.

// %% [markdown]
// ### tester.cpp

// %% [markdown]
// Next, I provide a tester program for my implementation. Here, I display my input matrices and the results of multiplying them in every test case. I test matrix multiplication on all three algorithms from 2 x 2 matrices to 16 x 16. The output of this tester is shown below:
// ![tester1.JPG](attachment:tester1.JPG)

// %% [markdown]
// ![tester2.JPG](attachment:tester2.JPG)

// %% [markdown]
// ![tester3.JPG](attachment:tester3.JPG)

// %% [markdown]
// ![tester4.JPG](attachment:tester4.JPG)

// %% [markdown]
// ![tester5.JPG](attachment:tester5.JPG)

// %% [markdown]
// ## main.cpp Comparison of the 3 Matrix-Matrix-Multiply Algorithms

// %% [markdown]
// Next, I compare the performance of the three multiplication methods using different values of $n$ from $n = 2, 4, 8, 16, 32, 64, 128, 256$. I use the **main()** function to measure and gather the running times for the comparison.

// %% [markdown]
// The output of **main()** produces the following formatted table of times:
// ![main1.JPG](attachment:main1.JPG)

// %% [markdown]
// Using the results from **main.cpp**, the following graph is used to plot the running times of these algorithms as functions of $n$:

// %% [markdown]
// ![3Algs_RunningTimes.png](attachment:3Algs_RunningTimes.png)

// %% [markdown]
// The three algorithms perform roughly the same until around $n=64$, where the Recursive and Strassen methods start to take significantly more time than the Iterative method. The Strassen method outperforms the Recursive method consistently. **main.cpp** was run over a dozen times with results nearly identical to the one displayed here. Further testing will need to be done to make a conclusion about whether any of the three algorithms is actually significantly faster or more efficient than the other two.

// %% [markdown]
// ## Part 2:  Interval scheduling/activity selection problem

// %% [markdown]
// In this Part 2, I evaluate the strategy of calculating for every activity $a_{i}$ how many activities start after $f_{i}$ ($a_{i}$ finish time) and selecting the activity with the maximum number of those activities first. I answer the following question: Does this strategy lead to an optimal solution?
